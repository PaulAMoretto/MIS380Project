# %%
# @Title Housing Analysis: Pre and Post Marijuana Legalization

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("HPI_AT_BDL_state.csv")

# %%
df = df.dropna()

# %%
df
# Out:
#         State Abbreviation  FIPS  Year Annual Change (%)     HPI  \
# 0     Alabama           AL     1  1975                 .  100.00
# 1     Alabama           AL     1  1976               6.7  106.70
# 2     Alabama           AL     1  1977                10  117.37
# 3     Alabama           AL     1  1978              8.38  127.21
# 4     Alabama           AL     1  1979             10.73  140.86
# ...       ...          ...   ...   ...               ...     ...
# 2392  Wyoming           WY    56  2017              1.53  562.49
# 2393  Wyoming           WY    56  2018              3.52  582.27
# 2394  Wyoming           WY    56  2019              4.36  607.64
# 2395  Wyoming           WY    56  2020              3.72  630.24
# 2396  Wyoming           WY    56  2021              9.36  689.26
#
#       HPI with 1990 base  HPI with 2000 base  Legal
# 0                  49.74               36.16      0
# 1                  53.08               38.58      0
# ...

# %%
#cleaning rows that have no reference to a previous year in the annual change, has no meaning.
index = 0
for i in df['Annual Change (%)']:
    if i == ".":
        df.drop([index],axis=0, inplace=True)
    index = index +1

# %%
df
# Out:
#         State Abbreviation  FIPS  Year Annual Change (%)     HPI  \
# 1     Alabama           AL     1  1976               6.7  106.70
# 2     Alabama           AL     1  1977                10  117.37
# 3     Alabama           AL     1  1978              8.38  127.21
# 4     Alabama           AL     1  1979             10.73  140.86
# 5     Alabama           AL     1  1980              4.81  147.64
# ...       ...          ...   ...   ...               ...     ...
# 2392  Wyoming           WY    56  2017              1.53  562.49
# 2393  Wyoming           WY    56  2018              3.52  582.27
# 2394  Wyoming           WY    56  2019              4.36  607.64
# 2395  Wyoming           WY    56  2020              3.72  630.24
# 2396  Wyoming           WY    56  2021              9.36  689.26
#
#       HPI with 1990 base  HPI with 2000 base  Legal
# 1                  53.08               38.58      0
# 2                  58.39               42.44      0
# ...

# %%
df.to_csv("naRmData.csv")
